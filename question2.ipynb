# %% [markdown]
# <a href="https://colab.research.google.com/github/fbildirici/PhDCoursesAI/blob/main/question2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tabula-py
# !pip install plotly
# !pip install openpyxl
import pandas as pd

# %%
import pandas as pd
import tabula
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Tabloyu PDF'den çıkar
file_path = "EK1.pdf" # dosya adı doğru olmalı

# Tüm tabloları tek seferde çıkar
tables = tabula.read_pdf(file_path, pages='all', multiple_tables=True)

# Kaç tablo çıkarıldığını kontrol edelim
print(f"Çıkarılan tablo sayısı: {len(tables)}")
# Out:
# WARNING:tabula.backend:Failed to import jpype dependencies. Fallback to subprocess.
# WARNING:tabula.backend:No module named 'jpype'
# WARNING:tabula.backend:Got stderr: Jun 21, 2025 5:26:21 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Jun 21, 2025 5:26:21 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Jun 21, 2025 5:26:21 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 17 fonts
# Jun 21, 2025 5:26:29 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'Tahoma'
# Jun 21, 2025 5:26:30 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'Tahoma'
# Çıkarılan tablo sayısı: 108

# %%
# İlk birkaç tabloyu kontrol edelim
for i, table in enumerate(tables[:108]):
    print(f"Tablo {i+1}")
    display(table.head())
# Out:
# Tablo 1
#    Öğretmen Eğitim Kurumu Okul /Sınıf  Unnamed: 0   Öğrenci Sayısı  \
# 0                              Sayısı         NaN         Toplam E
# 1  Okul Öncesi Eğitimi Toplamı 13.692         NaN  358.499 186.912
#
#        Unnamed: 1
# 0        K Sayısı
# 1  171.587 19.122
# Tablo 2
#   Anaokulları Toplamı  783  51.723  27.361  24.362  2.640
# 0       (Resmi +Özel)  NaN     NaN     NaN     NaN    NaN
# Tablo 3
# Empty DataFrame
# Columns: [Bağımsız Anaokulları (Özel), 300, 9.059, 4.815, 4.244, 620]
# Index: []
# Tablo 4
# Empty DataFrame
# Columns: [Azınlık, 3, 21, 12, 9, 10]
# Index: []
# Tablo 5
# Empty DataFrame
# Columns: [Uluslar Arası, 0, 0.1, 0.2, 0.3, 0.4]
# Index: []
# Tablo 6
# Empty DataFrame
# Columns: [Anasınıfları (Resmi), 11.230, 275.725, 143.469, 132.256, 11.115]
# Index: []
# Tablo 7
#   Ortaöğretim Gen.Müd.Bağlı Okullar  33  694  402  292  45
# 0                     Bün.Anasınıfı NaN  NaN  NaN  NaN NaN
# Tablo 8
# ...
